# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Book1.csv', header=None)
df
# Out:
#               0                                                  1  \
# 0             I  感染症及寄生蟲病 Certain infectious and parasitic dise...
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ..          ...                                                ...
# 176         NaN                                                NaN
# 177         NaN                                                NaN
# 178         NaN                                                NaN
# 179         NaN                                                NaN
# 180  不詳 Unknown                                                NaN
#
#                                                      2   3   4   5  \
# 0                                                  NaN NaN NaN NaN
# ...

# %%
df_new = df[[6, 7]]
df_new[7]
# Out:
# 0       22,554
# 1        1,371
# 2        5,349
# 3           71
# 4          345
#          ...
# 176         87
# 177         17
# 178        205
# 179     37,633
# 180     14,439
# Name: 7, Length: 181, dtype: object

# %%
df_new[7] = df_new[7].str.strip()
df_new[7] = df_new[7].str.replace(',', '')
df_new[7] = pd.to_numeric(df_new[7], errors='coerce')
df_new[7]
# Out:
# /var/folders/t4/nb6s9xh918z38nfhtrby07q80000gn/T/ipykernel_16816/1044336741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new[7] = df_new[7].str.strip()
# /var/folders/t4/nb6s9xh918z38nfhtrby07q80000gn/T/ipykernel_16816/1044336741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new[7] = df_new[7].str.replace(',', '')
# /var/folders/t4/nb6s9xh918z38nfhtrby07q80000gn/T/ipykernel_16816/1044336741.py:3: SettingWithCopyWarning:
# ...

# %%
df_new = df_new.sort_values(by=[7], ascending=False)
df_new
# Out:
#                         6      7
# 85                J00-J99  65931
# 86                J00-J11  60110
# 156               R00-R99  45046
# 94                K00-K95  41404
# 160  remainder of R00-R99  40363
# ..                    ...    ...
# 20                    C43      9
# 33                C70,C72      8
# 31                    C69      4
# 170                 T70.3      3
# 149                   O82      2
#
# [181 rows x 2 columns]

# %%
df_new_40 = df_new.head(40)

# %%
df_new_40.index
# Out:
# Index([ 85,  86, 156,  94, 160, 174, 179, 115, 119,  68,  71, 161,  88,  50,
#        130,  73,   0, 117, 167,  52,  90,  74,  99,   6, 128, 118, 180,  62,
#        140, 104,  53,  72, 123,  67,   7, 116,  51, 139,  97, 158],
#       dtype='int64')

# %%
top_40_ICD = df.loc[df_new_40.index]

# %%
top_40_ICD.to_csv('top_40_ICD.csv')

# %%
top_40_ICD.to_csv('top_40_ICD.csv', encoding='utf-8-sig', index=False)
